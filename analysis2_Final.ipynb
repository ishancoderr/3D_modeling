# %% [markdown]
# <a href="https://colab.research.google.com/github/ishancoderr/3D_modeling/blob/main/analysis2_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from statsmodels.tools.eval_measures import mse, rmse

# %% [markdown]
# **Importing the dataset**

# %%
dataset = pd.read_csv('/content/sample_data/storks.csv')
x= dataset.iloc[:, 2:3].values #number of storks
y = dataset.iloc[:, 1:2].values

# %% [markdown]
# **Splitting the dataset into the Training set and Test set**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %% [markdown]
# **Training the Simple Linear Regression model on the Training set**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# **Visualising the Training set results**

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('number of storks vs Area of land (Training set)')
plt.xlabel('number of storks ')
plt.ylabel('Area of land ')
plt.show()

# %% [markdown]
# **Resample Dataset**

# %%
import statsmodels.api as sm

# %%
print('Training Data Count: {}'.format(X_train.shape[0]))

print('Testing Data Count: {}'.format(X_test.shape[0]))
# Out:
# Training Data Count: 11
# Testing Data Count: 6

# %%
x=X_train
y=y_train

# %%
def resample_with_replacement(x, y):
 

  # Get array of indices for resampled points
  sample_ = np.random.choice(len(x), size=len(x), replace=True)

  # Sample from x and y according to sample_
  x_ = x[sample_]
  y_ = y[sample_]

  return x_, y_


with plt.xkcd():
  fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
  ax1.scatter(x, y)
  ax1.set(title='Original', xlabel='x', ylabel='y')

  x_, y_ = resample_with_replacement(x, y)
  ax2.scatter(x_, y_, color='c')

  ax2.set(title='Resampled', xlabel='x', ylabel='y',
          xlim=ax1.get_xlim(), ylim=ax1.get_ylim());

# %% [markdown]
# **models are fitted**

# %%
X_ = sm.add_constant(x_)

results = sm.OLS(y_, X_).fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     1.224
# Date:                Thu, 06 May 2021   Prob (F-statistic):              0.297
# Time:                        20:49:22   Log-Likelihood:                -149.89
# No. Observations:                  11   AIC:                             303.8
# Df Residuals:                       9   BIC:                             304.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.685e+05    9.1e+04      2.951      0.016    6.27e+04    4.74e+05
# ...

# %%
y_pre=results.predict(X_test)
y_predi=y_pre.tolist()
RMSE=sm.tools.eval_measures.rmse(y_test, y_predi)
print(RMSE)
print(y_predi)
print(y_test)
# Out:
# [172655.66321056 187620.89269175 171229.78120969 196463.26655721
#  196463.26655721 171253.78434978]
# [270486.40660765336, 290083.9619918676, 268552.78114307753, 301189.2433762556, 301189.2433762556, 268585.44373538456]
# [[83860], [357000], [41900], [93000], [237500], [43100]]

# %%
X_test = sm.add_constant(X_test)

y_pred= results.predict(X_test)

plt.figure(dpi = 75)

plt.scatter(y_test, y_pred)

plt.plot(y_test, y_test, color="red")

plt.xlabel("Actual ")

plt.ylabel("Estimated ")

plt.title("Model: Actual vs Estimated ")

plt.show()

# %% [markdown]
# **RMSE for ORGINAL**

# %%
RMSE=sm.tools.eval_measures.rmse(y_test, y_pred)
print(RMSE)
# Out:
# [119247.19675082]

# %% [markdown]
# **The steps are repeated many times and a distribution of the differences is plotted**

# %%
for i in range(5):

  x=x_
  y=y_

  def resample_with_replacement(x, y):
 

  # Get array of indices for resampled points
    sample_ = np.random.choice(len(x), size=len(x), replace=True)

  # Sample from x and y according to sample_
    x_ = x[sample_]
    y_ = y[sample_]

    return x_, y_


  with plt.xkcd():
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
    ax1.scatter(x, y)
    ax1.set(title='Original', xlabel='x', ylabel='y')

    x_, y_ = resample_with_replacement(x, y)
    ax2.scatter(x_, y_, color='c')

    ax2.set(title='Resampled', xlabel='x', ylabel='y',
            xlim=ax1.get_xlim(), ylim=ax1.get_ylim());

# %% [markdown]
# # **MODEL 02**

# %%
x= dataset.iloc[:, 2:3].values #number of storks
y = dataset.iloc[:, 3:4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('number of storks vs population (Training set)')
plt.xlabel('number of storks ')
plt.ylabel('Population ')
plt.show()

# %% [markdown]
# **Resample Dataset**

# %%
print('Training Data Count: {}'.format(X_train.shape[0]))

print('Testing Data Count: {}'.format(X_test.shape[0]))
# Out:
# Training Data Count: 11
# Testing Data Count: 6

# %%
x=X_train
y=y_train

# %%
def resample_with_replacement(x, y):
 

  # Get array of indices for resampled points
  sample_ = np.random.choice(len(x), size=len(x), replace=True)

  # Sample from x and y according to sample_
  x_ = x[sample_]
  y_ = y[sample_]

  return x_, y_


with plt.xkcd():
  fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
  ax1.scatter(x, y)
  ax1.set(title='Original', xlabel='x', ylabel='y')

  x_, y_ = resample_with_replacement(x, y)
  ax2.scatter(x_, y_, color='c')

  ax2.set(title='Resampled', xlabel='x', ylabel='y',
          xlim=ax1.get_xlim(), ylim=ax1.get_ylim());

# %% [markdown]
# **models are fitted**

# %%
X_ = sm.add_constant(x_)

results = sm.OLS(y_, X_).fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     1.521
# Date:                Thu, 06 May 2021   Prob (F-statistic):              0.249
# Time:                        19:47:31   Log-Likelihood:                -47.755
# No. Observations:                  11   AIC:                             99.51
# Df Residuals:                       9   BIC:                             100.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.2760      7.724      3.143      0.012       6.804      41.748
# ...

# %%
RMSE=sm.tools.eval_measures.rmse(y_test, y_preds)
print(RMSE)
# Out:
# [141712.64780364 116569.70534225 147058.11613994 131540.31597069
#  131540.31597069 146964.85439587]

# %%
X_test = sm.add_constant(X_test)

y_preds = results.predict(X_test)

plt.figure(dpi = 75)

plt.scatter(y_test, y_preds)

plt.plot(y_test, y_test, color="red")

plt.xlabel("Actual ")

plt.ylabel("Estimated ")

plt.title("Model: Actual vs Estimated ")

plt.show()

# %%
RMSE=sm.tools.eval_measures.rmse(y_test, y_preds)
print(RMSE)
# Out:
# [141712.64780364 116569.70534225 147058.11613994 131540.31597069
#  131540.31597069 146964.85439587]

# %%
for i in range(5):

  x=x_
  y=y_

  def resample_with_replacement(x, y):
 

  # Get array of indices for resampled points
    sample_ = np.random.choice(len(x), size=len(x), replace=True)

  # Sample from x and y according to sample_
    x_ = x[sample_]
    y_ = y[sample_]

    return x_, y_


  with plt.xkcd():
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
    ax1.scatter(x, y)
    ax1.set(title='Original', xlabel='x', ylabel='y')

    x_, y_ = resample_with_replacement(x, y)
    ax2.scatter(x_, y_, color='c')

    ax2.set(title='Resampled', xlabel='x', ylabel='y',
            xlim=ax1.get_xlim(), ylim=ax1.get_ylim());

# %% [markdown]
# **Explain whether we can be confident that one of the models explains more of the variability in the number of births than the other model.**

# %% [markdown]
# **Estimate appropriate confidence intervals for the difference in the RMSE values**
